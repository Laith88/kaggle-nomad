# %%
from __future__ import print_function
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

from keras.models import Sequential
from keras.layers import Input
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.datasets import mnist
from keras.utils import np_utils

import pandas as pd
import numpy as np

from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 35, 28

# %%
import keras.callbacks as kc

class Metrics(kc.Callback):
    def on_epoch_end(self, batch, logs={}):
        predict = np.asarray(self.model.predict(self.validation_data[0]))
        targ = self.validation_data[1]
        self.ginis=np.sqrt(np.square(np.log(predict + 1) - np.log(targ + 1)).mean())
        return
metrics = Metrics()

# %%
df_train = pd.read_csv("../data/train_new.csv")
np.log(df_train['formation_energy_ev_natom']+1)
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df_train.values)
scaled_features_df = pd.DataFrame(scaled_features, index=df_train.index, columns=df_train.columns)
features = list(set(df_train.columns.tolist()) - set(['formation_energy_ev_natom',
                                                'bandgap_energy_ev', 
                                                'id',
                                                'lattice_angle_alpha_degree_r',
                                                'lattice_angle_beta_degree_r',
                                                'lattice_angle_alpha_degree_r']))

X = scaled_features_df[features].values

# %%
X.shape
# Out:
# (2400, 397)

# %%
Xr = VarianceThreshold(threshold=0.001).fit_transform(X)

# %%
Xr.shape
# Out:
# (2400, 296)

# %%
def data():
    '''
    Data providing function:

    This function is separated from model() so that hyperopt
    won't reload data for each evaluation run.
    '''
    df_train = pd.read_csv("../data/train_new.csv")
    df_train['formation_energy_ev_natom'] = np.log(df_train['formation_energy_ev_natom']+1)
    df_train['bandgap_energy_ev'] = np.log(df_train['bandgap_energy_ev']+1)

    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df_train.values)
    scaled_features_df = pd.DataFrame(scaled_features, index=df_train.index, columns=df_train.columns)
    

    # store these off for predictions with unseen data
    Xmeans = scaler.mean_
    Xstds = scaler.scale_

    features = list(set(df_train.columns.tolist()) - set(['formation_energy_ev_natom',
                                                'bandgap_energy_ev', 
                                                'id',
                                                'lattice_angle_alpha_degree_r',
                                                'lattice_angle_beta_degree_r',
                                                'lattice_angle_alpha_degree_r']))
    targets = ['formation_energy_ev_natom', 'bandgap_energy_ev']

    y_e = scaled_features_df['formation_energy_ev_natom']
    y_be = scaled_features_df['bandgap_energy_ev']

    X = scaled_features_df[features].values
    X = VarianceThreshold(threshold=0.5).fit_transform(X)
    
    #train_size = int(0.7 * X.shape[0])
    #X_train, X_test, Y_train, Y_test = X[0:train_size], X[train_size:], y_be[0:train_size], y_be[train_size:]
    X_train, X_test, Y_train, Y_test = train_test_split(X, y_be, test_size=0.3, random_state=23)
    return X_train, X_test, Y_train, Y_test, Xmeans, Xstds

# %%
def model():
#     # Model
#     class Metrics(kc.Callback):
#         def on_epoch_end(self, batch, logs={}):
#             predict = np.asarray(self.model.predict(self.validation_data[0]))
#             targ = self.validation_data[1]
#             self.ginis=np.sqrt(np.square(np.log(predict + 1) - np.log(targ + 1)).mean())
#             return
#     metrics = Metrics()
    model = Sequential()
    model.add(Dense({{choice([1224,1512,1748])}}, input_dim=296, kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='tanh'))#{{choice(['relu', 'tanh', 'linear'])}}
    #model.add(Dropout(0.5))
    model.add(Dense({{choice([32, 64,88, 128,225,500])}}, kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='relu'))
    model.add(Dense({{choice([16,25, 32, 45])}}, kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='tanh'))
    model.add(Dense({{choice([32, 64,90, 128])}}, kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='relu'))
    model.add(Dense({{choice([2,4, 8, 16])}}, kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='tanh'))
    model.add(Dense(1,activation='linear', kernel_initializer='glorot_uniform'))
    
    # Compile model
    model.compile(loss='mean_squared_logarithmic_error', optimizer='adam' ,metrics=['mean_squared_logarithmic_error']) #{{choice(['rmsprop', 'adam', 'sgd'])}}
    
    earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
    #checkpointer = ModelCheckpoint(filepath='/tmp/model.hdf5',monitor='val_loss', verbose=0, save_best_only=True, period=1, mode='min')
    
    history = model.fit(X_train, Y_train, batch_size=25, epochs=50, validation_data=(X_test, Y_test), callbacks=[earlystopper], verbose=0)
    score, acc = model.evaluate(X_test, Y_test, verbose=0)
    print('_______________')
    print('Test accuracy:', np.sqrt(acc))
    print('_______________')
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
X_train, X_test, Y_train, Y_test, Xmeans, Xstds = data()

# %%
best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=750,
                                      trials=Trials(),
                                      notebook_name='DL_regression')
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Input
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.optimizers import RMSprop
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from keras.datasets import mnist
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from keras.wrappers.scikit_learn import KerasRegressor
# except:
#     pass
#
# try:
#     from sklearn.model_selection import cross_val_score, train_test_split
# except:
#     pass
#
# try:
#     from sklearn.model_selection import KFold
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from sklearn.pipeline import Pipeline
# except:
#     pass
#
# try:
#     from sklearn.feature_selection import VarianceThreshold
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from pylab import rcParams
# except:
#     pass
#
# try:
#     import keras.callbacks as kc
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dense': hp.choice('Dense', [1224,1512,1748]),
#         'Dense_1': hp.choice('Dense_1', ['relu', 'tanh', 'linear']),
#         'Dense_2': hp.choice('Dense_2', [32, 64,88, 128,225,500]),
#         'Dense_3': hp.choice('Dense_3', [16,25, 32, 45]),
#         'Dense_4': hp.choice('Dense_4', [32, 64,90, 128]),
#         'Dense_5': hp.choice('Dense_5', [2,4, 8, 16]),
#         'Dense_6': hp.choice('Dense_6', ['rmsprop', 'adam', 'sgd']),
#     }
#
# >>> Data
#    1:
#    2: '''
#    3: Data providing function:
#    4:
#    5: This function is separated from model() so that hyperopt
#    6: won't reload data for each evaluation run.
#    7: '''
#    8: df_train = pd.read_csv("../data/train_new.csv")
#    9: df_train['formation_energy_ev_natom'] = np.log(df_train['formation_energy_ev_natom']+1)
#   10: df_train['bandgap_energy_ev'] = np.log(df_train['bandgap_energy_ev']+1)
#   11:
#   12: scaler = StandardScaler()
#   13: scaled_features = scaler.fit_transform(df_train.values)
#   14: scaled_features_df = pd.DataFrame(scaled_features, index=df_train.index, columns=df_train.columns)
#   15:
#   16:
#   17: # store these off for predictions with unseen data
#   18: Xmeans = scaler.mean_
#   19: Xstds = scaler.scale_
#   20:
#   21: features = list(set(df_train.columns.tolist()) - set(['formation_energy_ev_natom',
#   22:                                             'bandgap_energy_ev',
#   23:                                             'id',
#   24:                                             'lattice_angle_alpha_degree_r',
#   25:                                             'lattice_angle_beta_degree_r',
#   26:                                             'lattice_angle_alpha_degree_r']))
#   27: targets = ['formation_energy_ev_natom', 'bandgap_energy_ev']
#   28:
#   29: y_e = scaled_features_df['formation_energy_ev_natom']
#   30: y_be = scaled_features_df['bandgap_energy_ev']
#   31:
#   32: X = scaled_features_df[features].values
#   33: X = VarianceThreshold(threshold=0.5).fit_transform(X)
#   34:
#   35: #train_size = int(0.7 * X.shape[0])
#   36: #X_train, X_test, Y_train, Y_test = X[0:train_size], X[train_size:], y_be[0:train_size], y_be[train_size:]
#   37: X_train, X_test, Y_train, Y_test = train_test_split(X, y_be, test_size=0.3, random_state=23)
#   38:
#   39:
#   40:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3: #     # Model
#    4: #     class Metrics(kc.Callback):
#    5: #         def on_epoch_end(self, batch, logs={}):
#    6: #             predict = np.asarray(self.model.predict(self.validation_data[0]))
#    7: #             targ = self.validation_data[1]
#    8: #             self.ginis=np.sqrt(np.square(np.log(predict + 1) - np.log(targ + 1)).mean())
#    9: #             return
#   10: #     metrics = Metrics()
#   11:     model = Sequential()
#   12:     model.add(Dense(space['Dense'], input_dim=296, kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='tanh'))#space['Dense_1']
#   13:     #model.add(Dropout(0.5))
#   14:     model.add(Dense(space['Dense_2'], kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='relu'))
#   15:     model.add(Dense(space['Dense_3'], kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='tanh'))
#   16:     model.add(Dense(space['Dense_4'], kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='relu'))
#   17:     model.add(Dense(space['Dense_5'], kernel_initializer='glorot_uniform',bias_initializer='zeros', activation='tanh'))
#   18:     model.add(Dense(1,activation='linear', kernel_initializer='glorot_uniform'))
#   19:
#   20:     # Compile model
#   21:     model.compile(loss='mean_squared_logarithmic_error', optimizer='adam' ,metrics=['mean_squared_logarithmic_error']) #space['Dense_6']
#   22:
#   23:     earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
#   24:     #checkpointer = ModelCheckpoint(filepath='/tmp/model.hdf5',monitor='val_loss', verbose=0, save_best_only=True, period=1, mode='min')
#   25:
#   26:     history = model.fit(X_train, Y_train, batch_size=25, epochs=50, validation_data=(X_test, Y_test), callbacks=[earlystopper], verbose=0)
#   27:     score, acc = model.evaluate(X_test, Y_test, verbose=0)
#   28:     print('_______________')
#   29:     print('Test accuracy:', np.sqrt(acc))
#   30:     print('_______________')
#   31:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   32:
# _______________
# Test accuracy: 0.089143799711
# _______________
# _______________
# Test accuracy: 0.449095851654
# _______________
# _______________
# Test accuracy: 0.105276910933
# _______________
# _______________
# Test accuracy: 0.0844873013232
# _______________
# _______________
# Test accuracy: 0.0836290570672
# _______________
# _______________
# Test accuracy: 0.0907187245766
# _______________
# _______________
# Test accuracy: 0.104973378743
# _______________
# _______________
# Test accuracy: 0.0858055467946
# _______________
# _______________
# Test accuracy: 0.090743789999
# _______________
# _______________
# Test accuracy: 0.0980272956185
# _______________
# _______________
# Test accuracy: 0.0957746143577
# _______________
# _______________
# Test accuracy: 0.0890032849204
# _______________
# _______________
# Test accuracy: 0.0910725092641
# _______________
# _______________
# Test accuracy: 0.109623559581
# _______________
# _______________
# Test accuracy: 0.0900177595641
# _______________
# _______________
# Test accuracy: 0.449095851654
# _______________
# _______________
# Test accuracy: 0.0887855196009
# _______________
# _______________
# Test accuracy: 0.0959108048808
# _______________
# _______________
# Test accuracy: 0.0890776749793
# _______________
# _______________
# Test accuracy: 0.108626331157
# _______________
# _______________
# Test accuracy: 0.0928073516841
# _______________
# _______________
# Test accuracy: 0.0895204747236
# _______________
# _______________
# Test accuracy: 0.0976828160709
# _______________
# _______________
# Test accuracy: 0.102066206286
# _______________
# _______________
# Test accuracy: 0.0934315257345
# _______________
# _______________
# Test accuracy: 0.0869867116747
# _______________
# _______________
# Test accuracy: 0.0959292364397
# _______________
# _______________
# Test accuracy: 0.108352489107
# _______________
# _______________
# Test accuracy: 0.0953120567586
# _______________
# _______________
# Test accuracy: 0.105316872209
# _______________
# _______________
# Test accuracy: 0.0896549124631
# _______________
# _______________
# Test accuracy: 0.116621696788
# _______________
# _______________
# Test accuracy: 0.088226643163
# _______________
# _______________
# Test accuracy: 0.0911618334487
# _______________
# _______________
# Test accuracy: 0.0888944792963
# _______________
# _______________
# Test accuracy: 0.0892459055237
# _______________
# _______________
# Test accuracy: 0.0969898230878
# _______________
# _______________
# Test accuracy: 0.132368581451
# _______________
# _______________
# Test accuracy: 0.0967794125564
# _______________
# _______________
# Test accuracy: 0.111366801394
# _______________
# _______________
# Test accuracy: 0.102814712588
# _______________
# _______________
# Test accuracy: 0.449095851654
# _______________
# _______________
# Test accuracy: 0.0862461447252
# _______________
# _______________
# Test accuracy: 0.0900710517173
# _______________
# _______________
# Test accuracy: 0.10063460288
# _______________
# _______________
# Test accuracy: 0.0972434361574
# _______________
# _______________
# Test accuracy: 0.0899610291253
# _______________
# _______________
# Test accuracy: 0.0926382891852
# _______________
# _______________
# Test accuracy: 0.0860020803361
# _______________
# _______________
# Test accuracy: 0.0921067945796
# _______________
# _______________
# Test accuracy: 0.0974217747605
# _______________
# _______________
# Test accuracy: 0.096891050511
# _______________
# _______________
# Test accuracy: 0.110483744833
# _______________
# _______________
# Test accuracy: 0.0937693153789
# _______________
# _______________
# Test accuracy: 0.0949291458123
# _______________
# _______________
# Test accuracy: 0.108558460537
# _______________
# _______________
# Test accuracy: 0.0867013840738
# _______________
# _______________
# Test accuracy: 0.0879148672956
# _______________
# _______________
# Test accuracy: 0.0897137718724
# _______________
# _______________
# Test accuracy: 0.0942484367029
# _______________
# _______________
# Test accuracy: 0.0953651333816
# _______________
# _______________
# Test accuracy: 0.0943651268592
# _______________
# _______________
# Test accuracy: 0.0947774555375
# _______________
# _______________
# Test accuracy: 0.102694705479
# _______________
# _______________
# Test accuracy: 0.110063271647
# _______________
# _______________
# Test accuracy: 0.449095851654
# _______________

# %%
best_run
# Out:
# {'Dense': 0,
#  'Dense_1': 0,
#  'Dense_2': 2,
#  'Dense_3': 1,
#  'Dense_4': 1,
#  'Dense_5': 3,
#  'Dense_6': 2}

# %%
np.sqrt(0.008)
# Out:
# 0.089442719099991588

# %%
best_model.get_config()
# Out:
# [{'class_name': 'Dense',
#   'config': {'activation': 'tanh',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 296),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'dtype': 'float32',
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_505',
#    'trainable': True,
#    'units': 1224,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_506',
#    'trainable': True,
#    'units': 88,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'tanh',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_507',
#    'trainable': True,
#    'units': 25,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_508',
#    'trainable': True,
#    'units': 64,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'tanh',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_509',
#    'trainable': True,
#    'units': 16,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'linear',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_510',
#    'trainable': True,
#    'units': 1,
#    'use_bias': True}}]

# %%
print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test, verbose=1))
# Out:
# Evalutation of best performing model:
# 720/720 [==============================] - 0s
# [0.008896124611298243, 0.008896124611298243]

# %% [markdown]
# # 0.007
# [{'class_name': 'Dense',
#   'config': {'activation': 'tanh',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 296),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'dtype': 'float32',
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_187',
#    'trainable': True,
#    'units': 1512,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_188',
#    'trainable': True,
#    'units': 128,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'tanh',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_189',
#    'trainable': True,
#    'units': 32,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_190',
#    'trainable': True,
#    'units': 64,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'tanh',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_191',
#    'trainable': True,
#    'units': 8,
#    'use_bias': True}},
#  {'class_name': 'Dense',
#   'config': {'activation': 'linear',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'name': 'dense_192',
#    'trainable': True,
#    'units': 1,
#    'use_bias': True}}]
